# %% [markdown]
# ## Analise de dados Macroeconomicos

# %%
chave = 'hd7yY6ARvKP36irEnxXA'

# %%
import nasdaqdatalink
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import investpy

# %% [markdown]
# # Nasdaq Datalink

# %%
nasdaqdatalink.api_config.api_key_environment_variable_exists= chave
juros_reais_EUA = nasdaqdatalink.get('FRED/EFFR')

# %%
juros_reais_EUA.tail()
# Out:
#             Value
# Date
# 2022-07-11   1.58
# 2022-07-12   1.58
# 2022-07-13   1.58
# 2022-07-14   1.58
# 2022-07-15   1.58

# %%
#limitar data
juros_reais_EUA1 = nasdaqdatalink.get('FRED/EFFR', start_date= '2022-01-01', end_data='2022-10-11')

# %%
juros_reais_EUA1
# Out:
#             Value
# Date
# 2022-01-03   0.08
# 2022-01-04   0.08
# 2022-01-05   0.08
# 2022-01-06   0.08
# 2022-01-07   0.08
# ...           ...
# 2022-07-11   1.58
# 2022-07-12   1.58
# 2022-07-13   1.58
# 2022-07-14   1.58
# 2022-07-15   1.58
#
# [135 rows x 1 columns]

# %%
uros_reais_EUA = nasdaqdatalink.get('FRED/EFFR', collapse='monthly')
#Pwg apenas o ultimo dia dos mes.

# %% [markdown]
# # Indicadores Macroeconomico

# %%
selic = nasdaqdatalink.get('BCB/432', start_date= '2020-01-01', end_data='2022-10-11')
selic.head()
# Out:
#             Value
# Date
# 2020-01-01    4.5
# 2020-01-02    4.5
# 2020-01-03    4.5
# 2020-01-04    4.5
# 2020-01-05    4.5

# %%
fig = go.Figure() 
fig.add_trace(go.Scatter(name='SELIC', x=selic.index, y=selic.Value)) 
fig.show()
# Out:
# <div>                            <div id="307d4725-29a4-4146-8680-d9554a260a40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("307d4725-29a4-4146-8680-d9554a260a40")) {                    Plotly.newPlot(                        "307d4725-29a4-4146-8680-d9554a260a40",                        [{"name":"SELIC","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-
# ...

# %%
#IPCA Acumlado

ipca = nasdaqdatalink.get('BCB/13522', start_date= '2000-01-01', end_data='2022-08-20')

# %%
fig = go.Figure() 
fig.add_trace(go.Scatter(name='IPCA', x=ipca.index, y=ipca.Value)) 
fig.update_layout(title_text='IPCA', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="0ede970c-4e44-4a26-95e2-9ba3b186a080" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ede970c-4e44-4a26-95e2-9ba3b186a080")) {                    Plotly.newPlot(                        "0ede970c-4e44-4a26-95e2-9ba3b186a080",                        [{"name":"IPCA","x":["2000-01-31T00:00:00","2000-02-29T00:00:00","2000-03-31T00:00:00","2000-04-30T00:00:00","2000-05-31T00:00:00","2000-06-30T00:00:00","2000-07-31T00:00:00","2000-08-31T00:00:00","2000-09-30T00:00:00","2000-10-31T00:00:00","2000-11-30T00:00:00","2000-12-31T00:00:00","2001-01-31T00:00:00","2001-02-28T00:00:00","2001-03-31T00:00:00","2001-04-30T00:00:00","2001-05-31T00:00:00","2001-06-30T00:00:00","2001-07-31T00:00:00","2001-08-31T00:00:00","2001-0
# ...

# %%
#Preços Administrado

ipca_adm = nasdaqdatalink.get('BCB/4449', start_date= '2000-01-01')

fig = go.Figure() 
fig.add_trace(go.Bar(name='IPCA_ADM', x=ipca_adm.index, y=ipca_adm.Value)) 
fig.update_layout(title_text='IPCA ADM', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="1e7b0a59-0cfe-476b-9b94-d79be099799a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e7b0a59-0cfe-476b-9b94-d79be099799a")) {                    Plotly.newPlot(                        "1e7b0a59-0cfe-476b-9b94-d79be099799a",                        [{"name":"IPCA_ADM","x":["2000-01-31T00:00:00","2000-02-29T00:00:00","2000-03-31T00:00:00","2000-04-30T00:00:00","2000-05-31T00:00:00","2000-06-30T00:00:00","2000-07-31T00:00:00","2000-08-31T00:00:00","2000-09-30T00:00:00","2000-10-31T00:00:00","2000-11-30T00:00:00","2000-12-31T00:00:00","2001-01-31T00:00:00","2001-02-28T00:00:00","2001-03-31T00:00:00","2001-04-30T00:00:00","2001-05-31T00:00:00","2001-06-30T00:00:00","2001-07-31T00:00:00","2001-08-31T00:00:00","20
# ...

# %%
#BCB/4448 - Bens Não comercializado
#BCB/4447 - Bens comercializado

# %%
#IGPM (Indice do Aluguel, energia)

igpm = nasdaqdatalink.get('BCB/189', start_date= '2000-01-01')

fig = go.Figure() 
fig.add_trace(go.Scatter(name='IGPM', x=igpm.index, y=igpm.Value)) 
fig.update_layout(title_text='IGPM', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="802a3812-d645-4fdf-b1f3-95475fe47967" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("802a3812-d645-4fdf-b1f3-95475fe47967")) {                    Plotly.newPlot(                        "802a3812-d645-4fdf-b1f3-95475fe47967",                        [{"name":"IGPM","x":["2000-01-31T00:00:00","2000-02-29T00:00:00","2000-03-31T00:00:00","2000-04-30T00:00:00","2000-05-31T00:00:00","2000-06-30T00:00:00","2000-07-31T00:00:00","2000-08-31T00:00:00","2000-09-30T00:00:00","2000-10-31T00:00:00","2000-11-30T00:00:00","2000-12-31T00:00:00","2001-01-31T00:00:00","2001-02-28T00:00:00","2001-03-31T00:00:00","2001-04-30T00:00:00","2001-05-31T00:00:00","2001-06-30T00:00:00","2001-07-31T00:00:00","2001-08-31T00:00:00","2001-0
# ...

# %%
#INCC (Indice nacional do custo da construção)

incc = nasdaqdatalink.get('BCB/192', start_date= '2000-01-01')

fig = go.Figure() 
fig.add_trace(go.Bar(name='INCC', x=incc.index, y=incc.Value)) 
fig.update_layout(title_text='INCC', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="a72df4d6-5372-4181-a085-ed28637c398d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a72df4d6-5372-4181-a085-ed28637c398d")) {                    Plotly.newPlot(                        "a72df4d6-5372-4181-a085-ed28637c398d",                        [{"name":"INCC","x":["2000-01-31T00:00:00","2000-02-29T00:00:00","2000-03-31T00:00:00","2000-04-30T00:00:00","2000-05-31T00:00:00","2000-06-30T00:00:00","2000-07-31T00:00:00","2000-08-31T00:00:00","2000-09-30T00:00:00","2000-10-31T00:00:00","2000-11-30T00:00:00","2000-12-31T00:00:00","2001-01-31T00:00:00","2001-02-28T00:00:00","2001-03-31T00:00:00","2001-04-30T00:00:00","2001-05-31T00:00:00","2001-06-30T00:00:00","2001-07-31T00:00:00","2001-08-31T00:00:00","2001-0
# ...

# %% [markdown]
# # Indice de Confiança

# %%
#Indice de confiança dos Serviços

confianca_servico = nasdaqdatalink.get('BCB/20339', start_date= '2002-01-01')

fig = go.Figure() 
fig.add_trace(go.Scatter(name='Sondagem dos Serviços', x=confianca_servico.index, y=confianca_servico.Value)) 
fig.update_layout(title_text='Confiança dos Serviços', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="283f25dc-1446-4210-bd54-1af0c24b8f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("283f25dc-1446-4210-bd54-1af0c24b8f91")) {                    Plotly.newPlot(                        "283f25dc-1446-4210-bd54-1af0c24b8f91",                        [{"name":"Sondagem dos Servi\u00e7os","x":["2008-06-30T00:00:00","2008-07-31T00:00:00","2008-08-31T00:00:00","2008-09-30T00:00:00","2008-10-31T00:00:00","2008-11-30T00:00:00","2008-12-31T00:00:00","2009-01-31T00:00:00","2009-02-28T00:00:00","2009-03-31T00:00:00","2009-04-30T00:00:00","2009-05-31T00:00:00","2009-06-30T00:00:00","2009-07-31T00:00:00","2009-08-31T00:00:00","2009-09-30T00:00:00","2009-10-31T00:00:00","2009-11-30T00:00:00","2009-12-31T00:00:00","2010-0
# ...

# %%
#Indice Confiança do consumidor

confianca_consumidor = nasdaqdatalink.get('BCB/4393', start_date= '2002-01-01')

fig = go.Figure() 
fig.add_trace(go.Scatter(name='Sondagem dos Consumidores', x=confianca_consumidor.index, y=confianca_consumidor.Value)) 
fig.update_layout(title_text='Confiança dos Consumidores', template='simple_white') 
fig.show() 

#Acima de 100 esta razoavelmente bacana.
# Out:
# <div>                            <div id="c6785ac4-bf72-44e8-abf1-f7b1963e6c95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6785ac4-bf72-44e8-abf1-f7b1963e6c95")) {                    Plotly.newPlot(                        "c6785ac4-bf72-44e8-abf1-f7b1963e6c95",                        [{"name":"Sondagem dos Consumidores","x":["2002-01-31T00:00:00","2002-02-28T00:00:00","2002-03-31T00:00:00","2002-04-30T00:00:00","2002-05-31T00:00:00","2002-06-30T00:00:00","2002-07-31T00:00:00","2002-08-31T00:00:00","2002-09-30T00:00:00","2002-10-31T00:00:00","2002-11-30T00:00:00","2002-12-31T00:00:00","2003-01-31T00:00:00","2003-02-28T00:00:00","2003-03-31T00:00:00","2003-04-30T00:00:00","2003-05-31T00:00:00","2003-06-30T00:00:00","2003-07-31T00:00:00","2003-08
# ...

# %% [markdown]
# # PIB

# %%
#PIB em dola ODA/BRA_NGDPD

pib = nasdaqdatalink.get('BCB/4380', start_date= '2000-01-01')

fig = go.Figure() 
fig.add_trace(go.Scatter(name='PIB', x=pib.index, y=pib.Value)) 
fig.update_layout(title_text='PIB', template='simple_white') 
fig.show() 

#Valores em Milhoes
# Out:
# <div>                            <div id="59805c2a-8669-4926-a8d4-b420cc777590" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59805c2a-8669-4926-a8d4-b420cc777590")) {                    Plotly.newPlot(                        "59805c2a-8669-4926-a8d4-b420cc777590",                        [{"name":"PIB","x":["2000-01-31T00:00:00","2000-02-29T00:00:00","2000-03-31T00:00:00","2000-04-30T00:00:00","2000-05-31T00:00:00","2000-06-30T00:00:00","2000-07-31T00:00:00","2000-08-31T00:00:00","2000-09-30T00:00:00","2000-10-31T00:00:00","2000-11-30T00:00:00","2000-12-31T00:00:00","2001-01-31T00:00:00","2001-02-28T00:00:00","2001-03-31T00:00:00","2001-04-30T00:00:00","2001-05-31T00:00:00","2001-06-30T00:00:00","2001-07-31T00:00:00","2001-08-31T00:00:00","2001-09
# ...

# %% [markdown]
# # Como isso afeta meus investimentos?

# %%
import investpy

# %%
mglu3 = investpy.get_stock_historical_data('MGLU3', country='Brazil', from_date='01/01/2019', to_date='26/08/2022')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 mglu3 = investpy.get_stock_historical_data('MGLU3', country='Brazil', from_date='01/01/2019', to_date='26/08/2022')
#
# File ~/anaconda3/lib/python3.9/site-packages/investpy/stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
mglu3
# Out:
#             Open  High   Low  Close     Volume Currency
# Date
# 2018-01-02  2.50  2.54  2.42   2.45   59427200      BRL
# 2018-01-03  2.44  2.51  2.39   2.42   41385600      BRL
# 2018-01-04  2.47  2.49  2.45   2.48   47936000      BRL
# 2018-01-05  2.48  2.50  2.42   2.43   30684800      BRL
# 2018-01-08  2.42  2.47  2.42   2.43   28796800      BRL
# ...          ...   ...   ...    ...        ...      ...
# 2022-08-22  3.68  3.89  3.61   3.82  160950096      BRL
# 2022-08-23  3.87  4.19  3.86   4.15  185541696      BRL
# 2022-08-24  4.14  4.66  4.14   4.50  280303616      BRL
# 2022-08-25  4.66  4.79  4.58   4.68  191202000      BRL
# 2022-08-26  4.73  4.76  4.45   4.58  151525104      BRL
#
# [1154 rows x 6 columns]

# %%
#Macroeconomicos 
selic2 = nasdaqdatalink.get("BCB/432", start_date="2018-01-01",end_date="2022-12-31") 
confianca_consumidor2 = nasdaqdatalink.get('BCB/4393', start_date='2018-01-01') 
pib4 = nasdaqdatalink.get("BCB/4380", start_date="2018-01-01") 
ipca2 = nasdaqdatalink.get("BCB/13522", start_date = '2018-01-01') 
incc2 = nasdaqdatalink.get('BCB/192', start_date='2018-01-01')

# %%
#Varejo eletronicos

mglu3 = investpy.get_stock_historical_data('MGLU3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

viia3 = investpy.get_stock_historical_data('VVAR3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

amer3 = investpy.get_stock_historical_data('LAME4', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')


#Moda/Vestuario

guar3 = investpy.get_stock_historical_data('GUAR3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
lren3 = investpy.get_stock_historical_data('LREN3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
amar3 = investpy.get_stock_historical_data('AMAR3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
arzz3 = investpy.get_stock_historical_data('ARZZ3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

#Supermercados Atacarejo

crfb3 = investpy.get_stock_historical_data('CRFB3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
pcar3 = investpy.get_stock_historical_data('PCAR4', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

# %%
#Construtoras

cyre3 = investpy.get_stock_historical_data('CYRE3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
mrve3 = investpy.get_stock_historical_data('MRVE3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
hbor3 = investpy.get_stock_historical_data('HBOR3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
dirr3 = investpy.get_stock_historical_data('DIRR3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

# %%
#Bancos

bbas3 = investpy.get_stock_historical_data('BBAS3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
sanb11 = investpy.get_stock_historical_data('SANB11', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
bpan4 = investpy.get_stock_historical_data('BPAN4', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

# %%
#Bens de Capital

embr3 = investpy.get_stock_historical_data('EMBR3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
rapt4 = investpy.get_stock_historical_data('RAPT4', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

# %%
#Commodities

petr4 = investpy.get_stock_historical_data('PETR4', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
prio3 = investpy.get_stock_historical_data('PRIO3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
enat3 = investpy.get_stock_historical_data('ENAT3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
vale3 = investpy.get_stock_historical_data('VALE3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
csna3 = investpy.get_stock_historical_data('CSNA3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')
suzb3 = investpy.get_stock_historical_data('SUZB3', country='Brazil', from_date='01/01/2018', to_date='26/08/2022')

# %%
#Indices Ibovespa

search_indices = investpy.search_quotes(text='ICON', n_results=5) 

for i in search_indices: 
    print(i)
# Out:
# {"id_": 987778, "name": "International Conveyors Ltd", "symbol": "ICON", "country": "india", "tag": "/equities/international-conveyors-bo", "pair_type": "stocks", "exchange": "BSE"}
# {"id_": 1177943, "name": "International Conveyors Ltd", "symbol": "ICON", "country": "india", "tag": "/equities/international-conveyors-bo?cid=1177943", "pair_type": "stocks", "exchange": "NSE"}
# {"id_": 101458, "name": "Island Concepts Indonesia Tbk", "symbol": "ICON", "country": "indonesia", "tag": "/equities/island-concept", "pair_type": "stocks", "exchange": "Jakarta"}
# {"id_": 992852, "name": "Icon Offshore Bhd", "symbol": "ICON", "country": "malaysia", "tag": "/equities/icon-offshore-bhd", "pair_type": "stocks", "exchange": "Kuala Lumpur"}
# {"id_": 17929, "name": "Consumption", "symbol": "ICON", "country": "brazil", "tag": "/indices/consumption", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
icon = search_indices[4].retrieve_historical_data(from_date='01/01/2000', to_date='27/08/2022')

# %%
#Gráfico comparativo SELIC vs MGLU3
fig = make_subplots(rows=1, cols=1, specs=[[{'secondary_y': True}]]) 
fig.add_trace(go.Scatter(name='SELIC', x=selic2.index, y=selic2.Value), row=1, col=1) 
fig.add_trace(go.Scatter(name='MGLU3', x=mglu3.index, y=mglu3.Close), row=1, col=1, secondary_y=False) 
fig.update_layout(title_text='SELIC vs MGLU3', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="6c661eda-9443-499c-958d-4bea65f657df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c661eda-9443-499c-958d-4bea65f657df")) {                    Plotly.newPlot(                        "6c661eda-9443-499c-958d-4bea65f657df",                        [{"name":"SELIC","x":["2018-01-01T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-06T00:00:00","2018-01-07T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-13T00:00:00","2018-01-14T00:00:00","2018-01-15T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-20T00:00:00","2018-
# ...

# %%
fig = make_subplots(rows=1, cols=1, specs=[[{'secondary_y': True}]]) 
fig.add_trace(go.Scatter(name='SELIC', x=ipca2.index, y=ipca2.Value), row=1, col=1) 
fig.add_trace(go.Scatter(name='MGLU3', x=mglu3.index, y=mglu3.Close), row=1, col=1, secondary_y=False) 
fig.update_layout(title_text='IPCA vs MGLU3', template='simple_white') 
fig.show()
# Out:
# <div>                            <div id="a3ae8496-18f1-4877-a0d6-3743d894cce4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3ae8496-18f1-4877-a0d6-3743d894cce4")) {                    Plotly.newPlot(                        "a3ae8496-18f1-4877-a0d6-3743d894cce4",                        [{"name":"SELIC","x":["2018-01-31T00:00:00","2018-02-28T00:00:00","2018-03-31T00:00:00","2018-04-30T00:00:00","2018-05-31T00:00:00","2018-06-30T00:00:00","2018-07-31T00:00:00","2018-08-31T00:00:00","2018-09-30T00:00:00","2018-10-31T00:00:00","2018-11-30T00:00:00","2018-12-31T00:00:00","2019-01-31T00:00:00","2019-02-28T00:00:00","2019-03-31T00:00:00","2019-04-30T00:00:00","2019-05-31T00:00:00","2019-06-30T00:00:00","2019-07-31T00:00:00","2019-08-31T00:00:00","2019-
# ...
